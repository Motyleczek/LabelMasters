# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls '/content/gdrive/My Drive/projekt_magisterski'
# Out:
# config_test.yaml   images	  runs
# config_train.yaml  labels	  tesseract_sandbox.ipynb
# config.yaml	   results_saved  trainYoloV8CostumDataset.ipynb

# %%
ROOT_DIR = '/content/gdrive/My Drive/projekt_magisterski'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 3.2 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...

# %%
import os

from ultralytics import YOLO


# # load a model, here yolo v8 nano
# model = YOLO("yolov8n.yaml")


# # use/train the model
# results = model.train(data=os.path.join(ROOT_DIR, "config.yaml"), epochs=120)

# %%
# !scp -r /content/runs/detect/train5 '/content/gdrive/MyDrive/projekt_magisterski/runs'

# %%
# !ls

# %%
import shutil

# %%
model2 = YOLO("/content/gdrive/MyDrive/projekt_magisterski/runs/detect/train5/weights/best.pt")
results2 = model2(os.path.join(ROOT_DIR, "images/test"))
# Out:
# image 1/22 /content/gdrive/My Drive/projekt_magisterski/images/test/17106954832442256343623864406657 - Eliza Komperda.jpg: 640x480 1 uwagi, 68.3ms
# image 2/22 /content/gdrive/My Drive/projekt_magisterski/images/test/17108248916082116494927008903672 - Eliza Komperda.jpg: 640x480 1 odbiorca, 6.3ms
# image 3/22 /content/gdrive/My Drive/projekt_magisterski/images/test/1710835572566 - Miłosz Bączek.jpg: 640x416 1 odbiorca, 66.5ms
# image 4/22 /content/gdrive/My Drive/projekt_magisterski/images/test/20240319_220247 - Marek Lechowicz.jpg: 640x448 1 nadawca, 60.8ms
# image 5/22 /content/gdrive/My Drive/projekt_magisterski/images/test/IMG_20240313_110124 - Klaudia Komperda.jpg: 640x384 (no detections), 100.4ms
# image 6/22 /content/gdrive/My Drive/projekt_magisterski/images/test/IMG_2886 - Katarzyna Cicha.jpg: 640x448 1 odbiorca, 8.3ms
# image 7/22 /content/gdrive/My Drive/projekt_magisterski/images/test/IMG_4518.jpeg: 640x480 1 odbiorca, 7.1ms
# ...

# %%
import matplotlib.pyplot as plt
plt.imshow(results2[9].plot())

# %%
results2[0].numpy()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-aa50f056789b> in <cell line: 1>()
# ----> 1 results2[0].numpy()
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/results.py in numpy(self)
#     394             interoperability with numpy-based libraries or when CPU-based operations are required.
#     395         """
# --> 396         return self._apply("numpy")
#     397
#     398     def cuda(self):
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/results.py in _apply(self, fn, *args, **kwargs)
#     357             v = getattr(self, k)
#     358             if v is not None:
# --> 359                 setattr(r, k, getattr(v, fn)(*args, **kwargs))
#     360         return r
#     361
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/engine/results.py in numpy(self)
#     110             <class 'numpy.ndarray'>
# ...

# %%
import pickle

# %%
# zapis testowych wyników

with open('results_saved/test/test_results.pkl', 'wb') as file:
    pickle.dump(results2, file)

# %%
# zapis wyników treningowych
results_train = model2(os.path.join(ROOT_DIR, "images/train"))

with open('results_saved/train/train_results.pkl', 'wb') as file:
    pickle.dump(results_train, file)
# Out:
# image 1/79 /content/gdrive/My Drive/projekt_magisterski/images/train/IMG_0.jpeg: 640x480 1 nadawca, 1 odbiorca, 1 uwagi, 7.8ms
# image 2/79 /content/gdrive/My Drive/projekt_magisterski/images/train/IMG_1.jpeg: 640x480 1 nadawca, 1 odbiorca, 1 uwagi, 7.6ms
# image 3/79 /content/gdrive/My Drive/projekt_magisterski/images/train/IMG_10.jpeg: 640x480 1 nadawca, 1 odbiorca, 1 uwagi, 7.1ms
# image 4/79 /content/gdrive/My Drive/projekt_magisterski/images/train/IMG_11.jpeg: 640x480 1 odbiorca, 2 uwagis, 6.8ms
# image 5/79 /content/gdrive/My Drive/projekt_magisterski/images/train/IMG_12.jpeg: 640x480 1 nadawca, 1 odbiorca, 1 uwagi, 7.1ms
# image 6/79 /content/gdrive/My Drive/projekt_magisterski/images/train/IMG_13.jpeg: 640x480 1 nadawca, 1 odbiorca, 2 uwagis, 35.4ms
# image 7/79 /content/gdrive/My Drive/projekt_magisterski/images/train/IMG_14.jpeg: 640x480 1 odbiorca, 1 uwagi, 12.3ms
# ...

# %%
# zapis wyników validacyjnych
results_val = model2(os.path.join(ROOT_DIR, "images/val"))

with open('results_saved/val/val_results.pkl', 'wb') as file:
    pickle.dump(results_val, file)
# Out:
# image 1/21 /content/gdrive/My Drive/projekt_magisterski/images/val/IMG_79.jpeg: 640x480 1 nadawca, 1 odbiorca, 1 uwagi, 26.9ms
# image 2/21 /content/gdrive/My Drive/projekt_magisterski/images/val/IMG_80.jpeg: 640x480 1 nadawca, 1 odbiorca, 1 uwagi, 8.3ms
# image 3/21 /content/gdrive/My Drive/projekt_magisterski/images/val/IMG_81.jpeg: 640x480 1 nadawca, 1 odbiorca, 1 uwagi, 22.4ms
# image 4/21 /content/gdrive/My Drive/projekt_magisterski/images/val/IMG_82.jpeg: 640x480 1 nadawca, 1 odbiorca, 1 uwagi, 39.7ms
# image 5/21 /content/gdrive/My Drive/projekt_magisterski/images/val/IMG_83.jpeg: 640x480 1 nadawca, 1 odbiorca, 1 uwagi, 41.7ms
# image 6/21 /content/gdrive/My Drive/projekt_magisterski/images/val/IMG_84.jpeg: 640x480 1 nadawca, 1 odbiorca, 1 uwagi, 31.1ms
# image 7/21 /content/gdrive/My Drive/projekt_magisterski/images/val/IMG_85.jpeg: 640x480 1 odbiorca, 1 uwagi, 6.6ms
# ...

# %%
# shutil.copytree('results_saved', '/content/gdrive/MyDrive/projekt_magisterski/results_saved')
# Out:
# '/content/gdrive/MyDrive/projekt_magisterski/results_saved'

# %%
# model2.val(data=ROOT_DIR + '/config_train.yaml')
# Out:
# Ultralytics YOLOv8.2.78 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# val: Scanning /content/gdrive/My Drive/projekt_magisterski/labels/train.cache... 79 images, 0 backgrounds, 0 corrupt: 100%|██████████| 79/79 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:18<00:00,  3.62s/it]
#                    all         79        237      0.981      0.902      0.977      0.712
#                nadawca         79         79          1      0.844      0.971      0.699
#               odbiorca         79         79       0.99      0.987      0.995      0.782
#                  uwagi         79         79      0.953      0.873      0.966      0.656
# Speed: 2.8ms preprocess, 11.6ms inference, 0.0ms loss, 3.8ms postprocess per image
# Results saved to runs/detect/val4
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1, 2])
# ...

# %%
shutil.copytree("runs/detect/val_of_train", "/content/gdrive/MyDrive/projekt_magisterski/runs/detect/val_of_train")
# Out:
# '/content/gdrive/MyDrive/projekt_magisterski/runs/detect/val_of_train'

# %%
results2.numpy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1f0ed9267d2a> in <cell line: 1>()
# ----> 1 results2.numpy()
#
# NameError: name 'results2' is not defined
